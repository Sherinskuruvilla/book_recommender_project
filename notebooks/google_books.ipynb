# %%
import requests
import pandas as pd
import time
import random
import re

# %%
def fetch_books(query, max_results=1000):
    """Fetch books for one query using pagination (up to max_results)."""
    books = []
    for start in range(0, max_results, 40):  # Google API allows 40 per page
        url = f"https://www.googleapis.com/books/v1/volumes?q={query}&startIndex={start}&maxResults=40"
        r = requests.get(url)
        data = r.json()
        
        if "items" not in data:
            break
        
        for item in data["items"]:
            info = item.get("volumeInfo", {})
            books.append({
                "Title": info.get("title"),
                "Authors": ", ".join(info.get("authors", [])) if "authors" in info else None,
                "Publisher": info.get("publisher"),
                "Published Date": info.get("publishedDate"),
                "Description": info.get("description"),
                "Page Count": info.get("pageCount"),
                "Categories": ", ".join(info.get("categories", [])) if "categories" in info else None,
                "Average Rating": info.get("averageRating"),
                "Ratings Count": info.get("ratingsCount"),
                "Language": info.get("language"),
                "Preview Link": info.get("previewLink"),
                "ISBNs": ", ".join([id["identifier"] for id in info.get("industryIdentifiers", [])]),
                 "Image": info.get("imageLinks", {}).get("thumbnail")
            })
        
        time.sleep(0.2)  # polite delay (avoid hitting API too hard)
    return books


def collect_books(target=10000):
    """Keep scraping queries until we have at least target unique books."""
    
    queries = [
        "harry potter books","pride","ninteen","great","solitude","mockingbird","catcher","ignited","lord of the rings","alchemist",
        "trial","wonderland","invisible","divine","margaritta","diary","one","iliad","beloved","gray","wrath","trial","bovary","odyssey",
        "love", "life", "data", "history", "science", "fiction","nonfiction","horror","thriller","magic","socialism",
        "poetry", "art", "music", "philosophy", "children", "technology", "health","fantasy","autobiography","humor","christian","crime",
        "education", "novel", "war", "business", "adventure", "culture", "future","travel","mystery","romance","religion",
        "politics","geography","film","movie","drama","mathematics","statistics","games","classics","animals","humans","psychology",
        "medicine","sports","biography","comedy","memoir","countries"
    ]
    
    all_books = []
    for q in queries:
        print(f" Fetching books for query: '{q}' ...")
        books = fetch_books(q, max_results=1000)  # try up to 1000 per query
        all_books.extend(books)
        
        # Convert to DataFrame & deduplicate
        df = pd.DataFrame(all_books).drop_duplicates(subset=["Title", "Authors"])
        print(f" After query '{q}': {len(df)} unique books")
        
        # Stop once we hit target
        if len(df) >= target:
            print(f" Reached {target} unique books!")
            return df
    
    return pd.DataFrame(all_books).drop_duplicates(subset=["Title", "Authors"])


# Run collector
books_df = collect_books(target=20000)

# Save to CSV
books_df.to_csv("../data/raw/googleapi_books.csv", index=False, encoding="utf-8-sig")
print(f" Saved {len(books_df)} books to googleapi_books.csv")
# Out:
#  Fetching books for query: 'harry potter books' ...
#  After query 'harry potter books': 306 unique books
#  Fetching books for query: 'pride' ...
#  After query 'pride': 616 unique books
#  Fetching books for query: 'ninteen' ...
#  After query 'ninteen': 877 unique books
#  Fetching books for query: 'great' ...
#  After query 'great': 1183 unique books
#  Fetching books for query: 'solitude' ...
#  After query 'solitude': 1485 unique books
#  Fetching books for query: 'mockingbird' ...
#  After query 'mockingbird': 1784 unique books
#  Fetching books for query: 'catcher' ...
#  After query 'catcher': 2086 unique books
#  Fetching books for query: 'ignited' ...
#  After query 'ignited': 2377 unique books
#  Fetching books for query: 'lord of the rings' ...
#  After query 'lord of the rings': 2659 unique books
#  Fetching books for query: 'alchemist' ...
#  After query 'alchemist': 2944 unique books
#  Fetching books for query: 'trial' ...
#  After query 'trial': 3232 unique books
#  Fetching books for query: 'wonderland' ...
#  After query 'wonderland': 3486 unique books
#  Fetching books for query: 'invisible' ...
#  After query 'invisible': 3770 unique books
#  Fetching books for query: 'divine' ...
#  After query 'divine': 4037 unique books
#  Fetching books for query: 'margaritta' ...
#  After query 'margaritta': 4317 unique books
#  Fetching books for query: 'diary' ...
#  After query 'diary': 4630 unique books
#  Fetching books for query: 'one' ...
#  After query 'one': 4893 unique books
#  Fetching books for query: 'iliad' ...
#  After query 'iliad': 5104 unique books
#  Fetching books for query: 'beloved' ...
#  After query 'beloved': 5364 unique books
#  Fetching books for query: 'gray' ...
#  After query 'gray': 5628 unique books
#  Fetching books for query: 'wrath' ...
#  After query 'wrath': 5877 unique books
#  Fetching books for query: 'trial' ...
#  After query 'trial': 5882 unique books
#  Fetching books for query: 'bovary' ...
#  After query 'bovary': 5973 unique books
#  Fetching books for query: 'odyssey' ...
#  After query 'odyssey': 6186 unique books
#  Fetching books for query: 'love' ...
#  After query 'love': 6430 unique books
#  Fetching books for query: 'life' ...
#  After query 'life': 6641 unique books
#  Fetching books for query: 'data' ...
#  After query 'data': 6910 unique books
#  Fetching books for query: 'history' ...
#  After query 'history': 7207 unique books
#  Fetching books for query: 'science' ...
#  After query 'science': 7437 unique books
#  Fetching books for query: 'fiction' ...
#  After query 'fiction': 7706 unique books
#  Fetching books for query: 'nonfiction' ...
#  After query 'nonfiction': 7998 unique books
#  Fetching books for query: 'horror' ...
#  After query 'horror': 8262 unique books
#  Fetching books for query: 'thriller' ...
#  After query 'thriller': 8534 unique books
#  Fetching books for query: 'magic' ...
#  After query 'magic': 8828 unique books
#  Fetching books for query: 'socialism' ...
#  After query 'socialism': 9082 unique books
#  Fetching books for query: 'poetry' ...
#  After query 'poetry': 9379 unique books
#  Fetching books for query: 'art' ...
#  After query 'art': 9576 unique books
#  Fetching books for query: 'music' ...
#  After query 'music': 9835 unique books
#  Fetching books for query: 'philosophy' ...
#  After query 'philosophy': 10124 unique books
#  Fetching books for query: 'children' ...
#  After query 'children': 10331 unique books
#  Fetching books for query: 'technology' ...
#  After query 'technology': 10585 unique books
#  Fetching books for query: 'health' ...
#  After query 'health': 10743 unique books
#  Fetching books for query: 'fantasy' ...
#  After query 'fantasy': 11038 unique books
#  Fetching books for query: 'autobiography' ...
#  After query 'autobiography': 11338 unique books
#  Fetching books for query: 'humor' ...
#  After query 'humor': 11596 unique books
#  Fetching books for query: 'christian' ...
#  After query 'christian': 11863 unique books
#  Fetching books for query: 'crime' ...
#  After query 'crime': 12078 unique books
#  Fetching books for query: 'education' ...
#  After query 'education': 12217 unique books
#  Fetching books for query: 'novel' ...
#  After query 'novel': 12408 unique books
#  Fetching books for query: 'war' ...
#  After query 'war': 12550 unique books
#  Fetching books for query: 'business' ...
#  After query 'business': 12680 unique books
#  Fetching books for query: 'adventure' ...
#  After query 'adventure': 12918 unique books
#  Fetching books for query: 'culture' ...
#  After query 'culture': 13130 unique books
#  Fetching books for query: 'future' ...
#  After query 'future': 13321 unique books
#  Fetching books for query: 'travel' ...
#  After query 'travel': 13498 unique books
#  Fetching books for query: 'mystery' ...
#  After query 'mystery': 13749 unique books
#  Fetching books for query: 'romance' ...
#  After query 'romance': 14054 unique books
#  Fetching books for query: 'religion' ...
#  After query 'religion': 14219 unique books
#  Fetching books for query: 'politics' ...
#  After query 'politics': 14475 unique books
#  Fetching books for query: 'geography' ...
#  After query 'geography': 14754 unique books
#  Fetching books for query: 'film' ...
#  After query 'film': 14979 unique books
#  Fetching books for query: 'movie' ...
#  After query 'movie': 15073 unique books
#  Fetching books for query: 'drama' ...
#  After query 'drama': 15244 unique books
#  Fetching books for query: 'mathematics' ...
#  After query 'mathematics': 15543 unique books
#  Fetching books for query: 'statistics' ...
#  After query 'statistics': 15698 unique books
#  Fetching books for query: 'games' ...
#  After query 'games': 15914 unique books
#  Fetching books for query: 'classics' ...
#  After query 'classics': 16122 unique books
#  Fetching books for query: 'animals' ...
#  After query 'animals': 16300 unique books
#  Fetching books for query: 'humans' ...
#  After query 'humans': 16577 unique books
#  Fetching books for query: 'psychology' ...
#  After query 'psychology': 16753 unique books
#  Fetching books for query: 'medicine' ...
#  After query 'medicine': 16926 unique books
#  Fetching books for query: 'sports' ...
#  After query 'sports': 17095 unique books
#  Fetching books for query: 'biography' ...
#  After query 'biography': 17351 unique books
#  Fetching books for query: 'comedy' ...
#  After query 'comedy': 17618 unique books
#  Fetching books for query: 'memoir' ...
#  After query 'memoir': 17843 unique books
#  Fetching books for query: 'countries' ...
#  After query 'countries': 18007 unique books
#  Saved 18007 books to google_books.csv
